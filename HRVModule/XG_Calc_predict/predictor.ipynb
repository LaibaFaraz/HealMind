# %%
from XGBoost_ import StressPredictor

# load the saved model
predictor = StressPredictor()

# predict stress from HRV values
result = predictor.predictSingle(sdnn=45.2, rmssd=38.7)

print(result['stressLabel'])
print(result['confidence'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from XGBoost_ import StressPredictor
#       3 # load the saved model
#       4 predictor = StressPredictor()
#
# ModuleNotFoundError: No module named 'XGBoost_'
